# %%
# importing libraries and making data frame from csv file
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

seasons_stats = pd.read_csv("Seasons_Stats.csv")
players = pd.read_csv("Players.csv")

# %%
#check for nulls
season_stats.isnull().sum()
# Out:
# Column1       0
# Year          0
# Player        0
# Pos           0
# Column2       0
# Age           0
# Tm            0
# G             0
# GS          694
# MP            0
# PER           5
# TS%          76
# 3PAr         88
# FTr          88
# ORB%          5
# DRB%          5
# TRB%          5
# AST%          5
# STL%          5
# BLK%          5
# TOV%         61
# USG%          5
# OWS           0
# DWS           0
# WS            0
# WS/48         5
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%          88
# 3P            0
# 3PA           0
# 3P%        3511
# 2P            0
# 2PA           0
# 2P%         117
# eFG%         88
# FT            0
# FTA           0
# FT%         745
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# dtype: int64

# %%
players.isnull().sum()
# Out:
# Index            0
# Player           0
# height           0
# weight           0
# collage        348
# born             0
# birth_city     469
# birth_state    482
# dtype: int64

# %%
seasons_stats.head()
# Out:
#    Column1  Year                Player Pos                   Column2  Age  \
# 0     5727  1980  Kareem Abdul-Jabbar*   C  Kareem Abdul-Jabbar*1980   32
# 1     5728  1980         Tom Abernethy  PF         Tom Abernethy1980   25
# 2     5729  1980           Alvan Adams   C           Alvan Adams1980   25
# 3     5730  1980       Tiny Archibald*  PG       Tiny Archibald*1980   31
# 4     5731  1980         Dennis Awtrey   C         Dennis Awtrey1980   31
#
#     Tm   G    GS    MP  ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  \
# 0  LAL  82   NaN  3143  ...  0.765  190  696  886  371   81  280  297  216
# 1  GSW  67   NaN  1222  ...  0.683   62  129  191   87   35   12   39  118
# 2  PHO  75   NaN  2168  ...  0.797  158  451  609  322  108   55  218  237
# 3  BOS  80  80.0  2864  ...  0.830   59  138  197  671  106   10  242  218
# 4  CHI  26   NaN   560  ...  0.640   29   86  115   40   12   15   27   66
#
#     PTS
# 0  2034
# 1   362
# 2  1118
# 3  1131
# 4    86
#
# ...

# %%
seasons_stats = seasons_stats.fillna(0)
seasons_stats = seasons_stats[seasons_stats.Tm != 'TOT']

# %%
# Function to create 'xGame' column, to calculate the average for stats per game
# x == DataFrame ; y == Column

def pergame(x, y):
    x[y + 'xG'] = round(x[y]/x['G'], 2)

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.distplot(seasons_stats['Age']);

plt.title("Age Distribution")
plt.show()
# Out:
# C:\Users\Amanu\.virtualenvs\Tekle_Amanuel_Capstone2-w0N8gz-z\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
seasons_stats['ppg'] = seasons_stats.PTS/seasons_stats.G

# %%
ppg = pd.DataFrame()
ppg['player'] = seasons_stats.groupby('Player').mean()['ppg'].index
ppg['ppg'] = seasons_stats.groupby('Player').mean()['ppg'].values
ppg['Games played'] = seasons_stats.groupby('Player').sum()['G'].values
ppg['points'] = seasons_stats.groupby('Player').mean()['PTS'].values
ppg = ppg.sort_values('ppg', ascending=False).head(10)
ppg
# Out:
#                   player        ppg  Games played       points
# 1892     Michael Jordan*  29.444797          1072  2152.800000
# 1673        LeBron James  27.121076          1061  2056.214286
# 1561        Kevin Durant  27.029466           703  1912.100000
# 982       George Gervin*  25.988089           547  2030.857143
# 384      Carmelo Anthony  24.884033          1053  1632.875000
# 1491        Karl Malone*  24.682985          1476  1943.578947
# 772   Dominique Wilkins*  24.342062          1148  1681.823529
# 1602         Kobe Bryant  24.207550          1346  1682.150000
# 69        Allen Iverson*  24.150273          1064  1372.850000
# 1646         Larry Bird*  23.754874           897  1676.230769
